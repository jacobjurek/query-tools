# %%
from query import QueryClient
import os

token = os.getenv("TOKEN")

# %%
Client = QueryClient(base_url="https://mapache.gauchoracing.com/api", 
token=token)

# %%
Client.query(['acu_cell1_temp'], 'gr24-main', 4).df
# Out:
#                           produced_at  acu_cell1_temp
# 0    2024-11-10 21:07:43.021357+00:00           20.50
# 1    2024-11-10 21:07:43.025972+00:00           20.50
# 2    2024-11-10 21:07:43.029847+00:00           20.50
# 3    2024-11-10 21:07:43.034264+00:00           20.50
# 4    2024-11-10 21:07:43.038407+00:00           20.50
# ...                               ...             ...
# 1325 2024-11-10 21:09:46.608795+00:00           31.25
# 1326 2024-11-10 21:09:46.612574+00:00           31.25
# 1327 2024-11-10 21:09:46.616795+00:00           31.25
# 1328 2024-11-10 21:09:46.621185+00:00           31.25
# 1329 2024-11-10 21:09:46.623443+00:00           31.25
#
# [1330 rows x 2 columns]
